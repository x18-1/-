# %% [markdown]
# ## 门控循环单元GRU
#
#
# <img src='photo/GRU_1.png'>
#
# <img src='photo/GRU_2.png'>

# %% [markdown]
# ### 公式：
#
#
# $$
# \begin{split}\begin{aligned}
# \mathbf{R}_t = \sigma(\mathbf{X}_t \mathbf{W}_{xr} + \mathbf{H}_{t-1} \mathbf{W}_{hr} + \mathbf{b}_r),\\
# \mathbf{Z}_t = \sigma(\mathbf{X}_t \mathbf{W}_{xz} + \mathbf{H}_{t-1} \mathbf{W}_{hz} + \mathbf{b}_z),
# \end{aligned}\end{split}
# \\
# \tilde{\mathbf{H}}_t = \tanh(\mathbf{X}_t \mathbf{W}_{xh} + \left(\mathbf{R}_t \odot \mathbf{H}_{t-1}\right) \mathbf{W}_{hh} + \mathbf{b}_h),
# \\
#
# \mathbf{H}_t = \mathbf{Z}_t \odot \mathbf{H}_{t-1}  + (1 - \mathbf{Z}_t) \odot \tilde{\mathbf{H}}_t.
# $$

# %% [markdown]
# ### 从零开始实现

# %%
import torch
from torch import nn
from d2l import torch as d2l

batch_size,num_steps = 32,35
train_iter, vocab = d2l.load_data_time_machine(batch_size,num_steps)

# %% [markdown]
# ### 初始化模型参数

# %%
def get_params(vocab_size,num_hiddens,device):
    num_inputs = num_outputs = vocab_size
    
    def normal(shape):
        return torch.randn(size=shape,device=device) * 0.01
    def three():
        return (normal((num_inputs, num_hiddens)),
                normal((num_hiddens, num_hiddens)),
                torch.zeros(num_hiddens, device=device))

    W_xz, W_hz, b_z = three()  # 更新门参数
    W_xr, W_hr, b_r = three()  # 重置门参数
    W_xh, W_hh, b_h = three()  # 候选隐状态参数
    # 输出层参数
    W_hq = normal((num_hiddens, num_outputs))
    b_q = torch.zeros(num_outputs, device=device)
    # 附加梯度
    params = [W_xz, W_hz, b_z, W_xr, W_hr, b_r, W_xh, W_hh, b_h, W_hq, b_q]
    for param in params:
        param.requires_grad_(True)
    return params

# %% [markdown]
# ### 定义模型

# %%
def init_gru_state(batch_size, num_hiddens, device):
    return (torch.zeros((batch_size, num_hiddens), device=device), )

# %%
def gru(inputs, state, params):
    W_xz, W_hz, b_z, W_xr, W_hr, b_r, W_xh, W_hh, b_h, W_hq, b_q = params
    H, = state
    outputs = []
    for X in inputs:
        Z = torch.sigmoid((X @ W_xz) + (H @ W_hz) + b_z)
        R = torch.sigmoid((X @ W_xr) + (H @ W_hr) + b_r)
        H_tilda = torch.tanh((X @ W_xh) + ((R * H) @ W_hh) + b_h)
        H = Z * H + (1 - Z) * H_tilda
        Y = H @ W_hq + b_q
        outputs.append(Y)
    return torch.cat(outputs, dim=0), (H,)

# %% [markdown]
# ### 训练与预测

# %%
vocab_size, num_hiddens, device = len(vocab), 256, d2l.try_gpu()
num_epochs, lr = 500, 1
model = d2l.RNNModelScratch(len(vocab), num_hiddens, device, get_params,
                            init_gru_state, gru)
d2l.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 5
#       2 num_epochs, lr = 500, 1
#       3 model = d2l.RNNModelScratch(len(vocab), num_hiddens, device, get_params,
#       4                             init_gru_state, gru)
# ----> 5 d2l.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\d2l\torch.py:798, in train_ch8(net, train_iter, vocab, lr, num_epochs, device, use_random_iter)
#     796 # Train and predict
#     797 for epoch in range(num_epochs):
# --> 798     ppl, speed = train_epoch_ch8(
#     799         net, train_iter, loss, updater, device, use_random_iter)
#     800     if (epoch + 1) % 10 == 0:
#     801         print(predict('time traveller'))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\d2l\torch.py:767, in train_epoch_ch8(net, train_iter, loss, updater, device, use_random_iter)
#     765 y = Y.T.reshape(-1)
#     766 X, y = X.to(device), y.to(device)
# --> 767 y_hat, state = net(X, state)
#     768 l = loss(y_hat, y.long()).mean()
#     769 if isinstance(updater, torch.optim.Optimizer):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\d2l\torch.py:711, in RNNModelScratch.__call__(self, X, state)
#     709 def __call__(self, X, state):
#     710     X = F.one_hot(X.T, self.vocab_size).type(torch.float32)
# --> 711     return self.forward_fn(X, state, self.params)
#
# Cell In [4], line 8, in gru(inputs, state, params)
#       6 Z = torch.sigmoid((X @ W_xz) + (H @ W_hz) + b_z)
#       7 R = torch.sigmoid((X @ W_xr) + (H @ W_hr) + b_r)
# ----> 8 H_tilda = torch.tanh((X @ W_xh) + ((R * H) @ W_hh) + b_h)
#       9 H = Z * H + (1 - Z) * H_tilda
#      10 Y = H @ W_hq + b_q
#
# KeyboardInterrupt:

# %% [markdown]
# ## 简洁实现

# %%
num_inputs = vocab_size
gru_layer = nn.GRU(num_inputs, num_hiddens)
model = d2l.RNNModel(gru_layer, len(vocab))
model = model.to(device)
d2l.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# perplexity 1.0, 118210.0 tokens/sec on cuda:0
# time traveller for so it will be convenient to speak of himwas e
# travelleryou can show black is white by argument said filby
